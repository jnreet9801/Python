# %%
import pandas as pd

# %%
path='C:/py/'
df=pd.read_csv(path+'cars_price.csv')

# %%
df.head()
# Out:
#    mileage  age  sell_price
# 0    69000    6       16200
# 1    72000    7       38000
# 2    65200    6       31000
# 3    15440    3       13000
# 4    23000    2       28000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['mileage'],df['sell_price'])

# %%
plt.scatter(df['age'],df['sell_price'])

# %%
x=df[['mileage','age']]
y=df['sell_price']

# %%
x
# Out:
#     mileage  age
# 0     69000    6
# 1     72000    7
# 2     65200    6
# 3     15440    3
# 4     23000    2
# 5     45630    4
# 6     75000    7
# 7     49000    4
# 8     65400    6
# 9     78920    7
# 10    48763    4
# 11    55200    5
# 12    45000    4
# 13    65400    6
# 14    54520    5
# 15    45702    6
# 16    12300    8
# 17    79000    7
# 18    48700    8
# 19    68700    6

# %%
y
# Out:
# 0     16200
# 1     38000
# 2     31000
# 3     13000
# 4     28000
# 5     24000
# 6     19000
# 7     62000
# 8     45100
# 9     27000
# 10    42000
# 11    15000
# 12    14000
# 13    16000
# 14    54000
# 15    45000
# 16    12000
# 17    17000
# 18    18000
# 19    16000
# Name: sell_price, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
len(x_train)
# Out:
# 16

# %%
len(x_test)
# Out:
# 4

# %%
x_train
# Out:
#     mileage  age
# 10    48763    4
# 17    79000    7
# 6     75000    7
# 13    65400    6
# 4     23000    2
# 2     65200    6
# 5     45630    4
# 14    54520    5
# 9     78920    7
# 7     49000    4
# 16    12300    8
# 11    55200    5
# 3     15440    3
# 0     69000    6
# 15    45702    6
# 12    45000    4

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([18001.67768318, 24819.89034115, 27478.55513444, 26962.52100085])

# %%
y_test
# Out:
# 18    18000
# 1     38000
# 19    16000
# 8     45100
# Name: sell_price, dtype: int64

# %%
clf.score(x_test,y_test)
# Out:
# -0.007196557991193897
