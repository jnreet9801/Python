# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
x=np.linspace(0,10,25)
y=x*x+2
print(x)
print(y)
# Out:
# [ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#   2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#   5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#   7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#  10.        ]
# [  2.           2.17361111   2.69444444   3.5625       4.77777778
#    6.34027778   8.25        10.50694444  13.11111111  16.0625
#   19.36111111  23.00694444  27.          31.34027778  36.02777778
#   41.0625      46.44444444  52.17361111  58.25        64.67361111
#   71.44444444  78.5625      86.02777778  93.84027778 102.        ]

# %%
pylab.plot(x,y, 'r')

# %%
pylab.subplot(1,2,1)

# %%
fig,axes=plt.subplots(dpi=150)
axes.plot(x,x+1,color='red')
axes.plot(x,x+2,color='red',marker='>')
axes.plot(x,x+3,color='black',marker='o',markersize=10,markerfacecolor='yellow')

# %%
fig,axes=plt.subplots(dpi=90)
axes.plot(x,x**2,alpha=.5)
axes.plot(x,x**2,alpha=.2)
axes.plot(x,x+3)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path='C:/py/'
df=pd.read_csv(path+'test.csv')

# %%
df
# Out:
#             date_time is_holiday  air_pollution_index  humidity  wind_speed  \
# 0    18/05/2017 00:00       None                   73        63           1
# 1    18/05/2017 00:00       None                  251        63           1
# 2    18/05/2017 00:00       None                   75        56           1
# 3    18/05/2017 01:00       None                   98        56           1
# 4    18/05/2017 01:00       None                  283        56           1
# ..                ...        ...                  ...       ...         ...
# 194  23/05/2017 01:00       None                  202        61           2
# 195  23/05/2017 02:00       None                   65        61           2
# 196  23/05/2017 02:00       None                  293        60           1
# 197  23/05/2017 03:00       None                  160        60           1
# 198  23/05/2017 04:00       None                  198        60           1
#
# ...

# %%
df.shape
# Out:
# (199, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date_time            199 non-null    object
#  1   is_holiday           199 non-null    object
#  2   air_pollution_index  199 non-null    int64
#  3   humidity             199 non-null    int64
#  4   wind_speed           199 non-null    int64
#  5   wind_direction       199 non-null    int64
#  6   visibility_in_miles  199 non-null    int64
#  7   dew_point            199 non-null    int64
#  8   temperature          199 non-null    float64
#  9   rain_p_h             199 non-null    int64
#  10  snow_p_h             199 non-null    int64
#  11  clouds_all           199 non-null    int64
#  12  weather_type         199 non-null    object
#  13  weather_description  199 non-null    object
# dtypes: float64(1), int64(9), object(4)
# memory usage: 21.9+ KB

# %%
df.isnull().sum()
# Out:
# date_time              0
# is_holiday             0
# air_pollution_index    0
# humidity               0
# wind_speed             0
# wind_direction         0
# visibility_in_miles    0
# dew_point              0
# temperature            0
# rain_p_h               0
# snow_p_h               0
# clouds_all             0
# weather_type           0
# weather_description    0
# dtype: int64

# %%
df['humidity']
# Out:
# 0      63
# 1      63
# 2      56
# 3      56
# 4      56
#        ..
# 194    61
# 195    61
# 196    60
# 197    60
# 198    60
# Name: humidity, Length: 199, dtype: int64

# %%
sns.barplot(df['humidity'],df['temperature'])
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='temperature'>

# %%
sns.barplot(df['wind_direction'],df['temperature'])
# Out:
# <AxesSubplot:xlabel='wind_direction', ylabel='temperature'>

# %%
sns.distplot(df['humidity'])
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='Density'>

# %%
 sns.jointplot(df['humidity'],df['temperature'],kind='kde')

# %%
sns.pairplot(df[['humidity','air_pollution_index','temperature']])

# %%
sns.pairplot(df[['humidity','wind_direction','wind_speed']])

# %%
sns.stripplot(df['weather_type'],df['temperature'],jitter=True)
# Out:
# <AxesSubplot:xlabel='weather_type', ylabel='temperature'>

# %%
sns.boxplot(df['humidity'],df['weather_type'])
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='weather_type'>

# %%
sns.barplot(df['humidity'],df['weather_type'])
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='weather_type'>

# %%
sns.countplot(df['weather_type'])
# Out:
# <AxesSubplot:xlabel='weather_type', ylabel='count'>

# %%
sns.pointplot(df['humidity'],df['weather_type'])
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='weather_type'>

# %%
sns.lmplot(x='humidity',y='temperature',data=df)

# %%
sns.lmplot(x='humidity',y='temperature',hue='weather_type',data=df)
