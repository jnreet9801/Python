# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os

# %%
# df= pd.read_csv(r'C:\Users\admin\Downloads\Pandas-Data-Science-Tasks-master\Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data\Sales_April_2019.csv')

all_months_data = pd.DataFrame()

files=[file for file in os.listdir('C:/Users/admin/Downloads/Pandas-Data-Science-Tasks-master/Pandas-Data-Science-Tasks-master/SalesAnalysis/Sales_Data/')]

for file in files:
    df= pd.read_csv('C:/Users/admin/Downloads/Pandas-Data-Science-Tasks-master/Pandas-Data-Science-Tasks-master/SalesAnalysis/Sales_Data/'+file)
    all_months_data = pd.concat([all_months_data,df])
                    
all_months_data.to_csv('all_data.csv', index=False)

# %%
path='Downloads/'
df1= pd.read_csv(path+'all_data.csv')
df1
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
df1.shape
# Out:
# (186850, 6)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
df1.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
df1
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
df1[df1.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address]
# Index: []

# %%
df1['Month']= df1['Order Date'].str[0:2]

# %%
df1
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address Month
# ...

# %%
df1['Month'].unique()
# Out:
# array(['04', '05', 'Or', '08', '09', '12', '01', '02', '03', '07', '06',
#        '11', '10'], dtype=object)

# %%
a=df1[df1['Month']=='Or']

# %%
a
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 519     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1149    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1155    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2878    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2893    Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...          ...      ...               ...         ...         ...
# 185164  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185551  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186563  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186632  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186738  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#         Purchase Address Month
# 519     Purchase Address    Or
# 1149    Purchase Address    Or
# 1155    Purchase Address    Or
# ...

# %%
df1=df1[df1['Month']!='Or']

# %%
df1
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address Month
# ...

# %%
df1['Month'].unique()
# Out:
# array(['04', '05', '08', '09', '12', '01', '02', '03', '07', '06', '11',
#        '10'], dtype=object)

# %%
df1['Month']=df1['Month'].astype('int')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12328\2742377074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Month']=df1['Month'].astype('int')

# %%
df1.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address', 'Month'],
#       dtype='object')

# %%
df1
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address  Month
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  object
#  3   Price Each        185950 non-null  object
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  int32
# dtypes: int32(1), object(6)
# memory usage: 10.6+ MB

# %%
df1['Quantity Ordered']=df1['Quantity Ordered'].astype(int)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12328\507367537.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Quantity Ordered']=df1['Quantity Ordered'].astype(int)

# %%
df1['Price Each']=df1['Price Each'].astype('float')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12328\2043165753.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Price Each']=df1['Price Each'].astype('float')

# %%
df1['Sales']=df1['Quantity Ordered']*df1['Price Each']
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12328\917160070.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Sales']=df1['Quantity Ordered']*df1['Price Each']

# %%
df1
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month   Sales
# ...

# %%
df1[df1['Sales']==3400]
# Out:
#        Order ID             Product  Quantity Ordered  Price Each  \
# 4717     181069  Macbook Pro Laptop                 2      1700.0
# 5219     181544  Macbook Pro Laptop                 2      1700.0
# 92026    210292  Macbook Pro Laptop                 2      1700.0
# 127265   200528  Macbook Pro Laptop                 2      1700.0
#
#             Order Date                       Purchase Address  Month   Sales
# 4717    04/27/19 21:01   668 Park St, San Francisco, CA 94016      4  3400.0
# 5219    04/22/19 12:48   731 11th St, New York City, NY 10001      4  3400.0
# 92026   06/08/19 09:00  953 Ridge St, San Francisco, CA 94016      6  3400.0
# 127265  05/13/19 13:40           643 4th St, Boston, MA 02215      5  3400.0

# %%
b=df1.groupby('Month').sum()
b
# Out:
#        Quantity Ordered  Price Each       Sales
# Month
# 1                 10903  1811768.38  1822256.73
# 2                 13449  2188884.72  2202022.42
# 3                 17005  2791207.83  2807100.38
# 4                 20558  3367671.02  3390670.24
# 5                 18667  3135125.13  3152606.75
# 6                 15253  2562025.61  2577802.26
# 7                 16072  2632539.56  2647775.76
# 8                 13448  2230345.42  2244467.88
# 9                 13109  2084992.09  2097560.13
# 10                22703  3715554.83  3736726.88
# 11                19798  3180600.68  3199603.20
# 12                28114  4588415.41  4613443.34

# %%
months=range(1,13)

plt.bar(months,b['Sales'])
plt.xticks(months)
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()

# %%
df1.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address', 'Month', 'Sales'],
#       dtype='object')

# %%
df1
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month   Sales
# ...

# %%
df1['City']=df1['city']=df1['Purchase Address'].apply(lambda x:x.split(',')[1])
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12328\2237191701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['City']=df1['city']=df1['Purchase Address'].apply(lambda x:x.split(',')[1])
# C:\Users\admin\AppData\Local\Temp\ipykernel_12328\2237191701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['City']=df1['city']=df1['Purchase Address'].apply(lambda x:x.split(',')[1])

# %%
df1
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month  \
# ...

# %%
df1.drop('city',inplace=True,axis=1)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12328\3970877643.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop('city',inplace=True,axis=1)

# %%
df1
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month  \
# ...

# %%
df1['Zipcode']=df1['Purchase Address'].apply(lambda x:x.split(',')[2])
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12328\3903490291.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Zipcode']=df1['Purchase Address'].apply(lambda x:x.split(',')[2])

# %%
df1
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month  \
# ...

# %%
df1['Place']=df1['Zipcode'].apply(lambda x:x.split(' ')[1])
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12328\3980302806.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Place']=df1['Zipcode'].apply(lambda x:x.split(' ')[1])

# %%
df1
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month  \
# ...

# %%
df1['combined']=df1['City']+', ' + df1['Place']
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12328\767677534.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['combined']=df1['City']+', ' + df1['Place']

# %%
df1
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month  \
# ...

# %%
df1.drop(['City','Zipcode','Place'],axis=1,inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12328\1064117182.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(['City','Zipcode','Place'],axis=1,inplace=True)

# %%
df1.rename(columns={'combined':'City'},inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12328\2997960729.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.rename(columns={'combined':'City'},inplace=True)

# %%
df1
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month  \
# ...

# %%
c=df1.groupby('City').sum().sort_values(by='Sales',ascending=False)
c
# Out:
#                     Quantity Ordered  Price Each   Month       Sales
# City
#  San Francisco, CA             50239  8211461.74  315520  8262203.91
#  Los Angeles, CA               33289  5421435.23  208325  5452570.80
#  New York City, NY             27932  4635370.83  175741  4664317.43
#  Boston, MA                    22528  3637409.77  141112  3661642.01
#  Atlanta, GA                   16602  2779908.20  104794  2795498.58
#  Dallas, TX                    16730  2752627.82  104620  2767975.40
#  Seattle, WA                   16553  2733296.01  104941  2747755.48
#  Portland, OR                  11303  1860558.22   70621  1870732.34
#  Austin, TX                    11153  1809873.61   69829  1819581.75
#  Portland, ME                   2750   447189.25   17144   449758.27

# %%
city=['San Francisco, CA','Los Angeles, CA','New York City, NY','Boston, MA','Atlanta, GA','Dallas TX','Seattle, WA','Portland, OR','Austin, TX','Portland, ME']

sns.set(rc={'figure.figsize':(20,5)})
plt.bar(city,c['Sales'])
plt.xticks(city)
plt.xlabel('City')
plt.ylabel('Sales')
plt.show()

# %%
df1.head(1)
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   176558  USB-C Charging Cable                 2       11.95
#
#        Order Date              Purchase Address  Month  Sales         City
# 0  04/19/19 08:46  917 1st St, Dallas, TX 75001      4   23.9   Dallas, TX

# %%
df1['Order Date']=pd.to_datetime(df1['Order Date'])
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12328\4074773695.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Order Date']=pd.to_datetime(df1['Order Date'])

# %%
df1['Hour']=df1['Order Date'].dt.hour
df1['Min']=df1['Order Date'].dt.minute
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12328\3656865026.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Hour']=df1['Order Date'].dt.hour
# C:\Users\admin\AppData\Local\Temp\ipykernel_12328\3656865026.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Min']=df1['Order Date'].dt.minute

# %%
df1.head(1)
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   176558  USB-C Charging Cable                 2       11.95
#
#            Order Date              Purchase Address  Month  Sales  \
# 0 2019-04-19 08:46:00  917 1st St, Dallas, TX 75001      4   23.9
#
#           City  Hour  Min
# 0   Dallas, TX     8   46

# %%
df1.groupby(['Hour']).count().sort_values(by='Sales',ascending=False).head(3)
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# Hour
# 19       12905    12905             12905       12905       12905
# 12       12587    12587             12587       12587       12587
# 11       12411    12411             12411       12411       12411
#
#       Purchase Address  Month  Sales   City    Min
# Hour
# 19               12905  12905  12905  12905  12905
# 12               12587  12587  12587  12587  12587
# 11               12411  12411  12411  12411  12411

# %%
plt.plot(hours, df1.groupby(['Hour']).count())
plt.xticks(hours)
plt.xlabel('Number of Orders')
plt.ylabel('Hour')
plt.show()

# %%
df1['Product'].unique()
# Out:
# array(['USB-C Charging Cable', 'Bose SoundSport Headphones',
#        'Google Phone', 'Wired Headphones', 'Macbook Pro Laptop',
#        'Lightning Charging Cable', '27in 4K Gaming Monitor',
#        'AA Batteries (4-pack)', 'Apple Airpods Headphones',
#        'AAA Batteries (4-pack)', 'iPhone', 'Flatscreen TV',
#        '27in FHD Monitor', '20in Monitor', 'LG Dryer', 'ThinkPad Laptop',
#        'Vareebadd Phone', 'LG Washing Machine', '34in Ultrawide Monitor'],
#       dtype=object)

# %%
df1.groupby(['Product']).count().sort_values(by='Quantity Ordered',ascending=False)
# Out:
#                             Order ID  Quantity Ordered  Price Each  \
# Product
# USB-C Charging Cable           21903             21903       21903
# Lightning Charging Cable       21658             21658       21658
# AAA Batteries (4-pack)         20641             20641       20641
# AA Batteries (4-pack)          20577             20577       20577
# Wired Headphones               18882             18882       18882
# Apple Airpods Headphones       15549             15549       15549
# Bose SoundSport Headphones     13325             13325       13325
# 27in FHD Monitor                7507              7507        7507
# iPhone                          6842              6842        6842
# 27in 4K Gaming Monitor          6230              6230        6230
# 34in Ultrawide Monitor          6181              6181        6181
# Google Phone                    5525              5525        5525
# Flatscreen TV                   4800              4800        4800
# ...

# %%
df1['Order ID'].value_counts()
# Out:
# 160873    5
# 178158    4
# 277875    4
# 196615    4
# 304802    4
#          ..
# 158177    1
# 158178    1
# 158179    1
# 158180    1
# 259357    1
# Name: Order ID, Length: 178437, dtype: int64

# %%
df1[df1['Order ID']=='160873']
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 66347   160873                    iPhone                 1      700.00
# 66348   160873  Lightning Charging Cable                 1       14.95
# 66349   160873  Apple Airpods Headphones                 1      150.00
# 66350   160873          Wired Headphones                 1       11.99
# 66351   160873              Google Phone                 1      600.00
#
#                Order Date                       Purchase Address  Month  \
# 66347 2019-02-10 10:24:00  702 River St, San Francisco, CA 94016      2
# 66348 2019-02-10 10:24:00  702 River St, San Francisco, CA 94016      2
# 66349 2019-02-10 10:24:00  702 River St, San Francisco, CA 94016      2
# 66350 2019-02-10 10:24:00  702 River St, San Francisco, CA 94016      2
# 66351 2019-02-10 10:24:00  702 River St, San Francisco, CA 94016      2
#
#         Sales                City  Hour  Min
# 66347  700.00   San Francisco, CA    10   24
# ...

# %%
sns.barplot(data=df1,x='Product',y='Sales')
plt.xticks(rotation='vertical')
plt.grid()
plt.show()

# %%
sns.barplot(data=df1,x='Product',y='Price Each')
plt.xticks(rotation='vertical')
plt.grid()
plt.show()
