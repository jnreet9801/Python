# %% [markdown]
# # Dairy Products Data Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('dairy_dataset.csv', encoding='unicode_escape')

# %%
df.head()
# Out:
#         Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 0      Telangana                   310.84              96    Medium
# 1  Uttar Pradesh                    19.19              44     Large
# 2     Tamil Nadu                   581.69              24    Medium
# 3      Telangana                   908.00              89     Small
# 4    Maharashtra                   861.95              21    Medium
#
#          Date  Product ID Product Name                 Brand  \
# 0  17/02/2022           5    Ice Cream           Dodla Dairy
# 1  01/12/2021           1         Milk                  Amul
# 2  28/02/2022           4       Yogurt           Dodla Dairy
# 3  09/06/2019           3       Cheese  Britannia Industries
# 4  14/12/2020           8   Buttermilk          Mother Dairy
#
#    Quantity (liters/kg)  Price per Unit  ...  Production Date  \
# 0                222.40           85.72  ...       27/12/2021
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4325 entries, 0 to 4324
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Location                             4325 non-null   object
#  1   Total Land Area (acres)              4325 non-null   float64
#  2   Number of Cows                       4325 non-null   int64
#  3   Farm Size                            4325 non-null   object
#  4   Date                                 4325 non-null   object
#  5   Product ID                           4325 non-null   int64
#  6   Product Name                         4325 non-null   object
#  7   Brand                                4325 non-null   object
#  8   Quantity (liters/kg)                 4325 non-null   float64
#  9   Price per Unit                       4325 non-null   float64
#  10  Total Value                          4325 non-null   float64
# ...

# %%
df.shape
# Out:
# (4325, 23)

# %%
df.isnull().sum()
# Out:
# Location                               0
# Total Land Area (acres)                0
# Number of Cows                         0
# Farm Size                              0
# Date                                   0
# Product ID                             0
# Product Name                           0
# Brand                                  0
# Quantity (liters/kg)                   0
# Price per Unit                         0
# Total Value                            0
# Shelf Life (days)                      0
# Storage Condition                      0
# Production Date                        0
# Expiration Date                        0
# Quantity Sold (liters/kg)              0
# Price per Unit (sold)                  0
# Approx. Total Revenue(INR)             0
# Customer Location                      0
# Sales Channel                          0
# Quantity in Stock (liters/kg)          0
# Minimum Stock Threshold (liters/kg)    0
# Reorder Quantity (liters/kg)           0
# ...

# %%
{features for features in df if df[features].isnull().sum()>0}
# Out:
# set()

# %%
df.columns
# Out:
# Index(['Location', 'Total Land Area (acres)', 'Number of Cows', 'Farm Size',
#        'Date', 'Product ID', 'Product Name', 'Brand', 'Quantity (liters/kg)',
#        'Price per Unit', 'Total Value', 'Shelf Life (days)',
#        'Storage Condition', 'Production Date', 'Expiration Date',
#        'Quantity Sold (liters/kg)', 'Price per Unit (sold)',
#        'Approx. Total Revenue(INR)', 'Customer Location', 'Sales Channel',
#        'Quantity in Stock (liters/kg)', 'Minimum Stock Threshold (liters/kg)',
#        'Reorder Quantity (liters/kg)'],
#       dtype='object')

# %%
from pandas_profiling import ProfileReport
profile=ProfileReport(df,explorative=True,dark_mode=True)
profile.to_file('output.html')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8000\1834145321.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
matplotlib.rcParams['figure.figsize']=(22,6)
s=sns.barplot(data=df,x='Location', y='Number of Cows')
for bars in s.containers:
    s.bar_label(bars)

# %%
df.head()
# Out:
#         Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 0      Telangana                   310.84              96    Medium
# 1  Uttar Pradesh                    19.19              44     Large
# 2     Tamil Nadu                   581.69              24    Medium
# 3      Telangana                   908.00              89     Small
# 4    Maharashtra                   861.95              21    Medium
#
#          Date  Product ID Product Name                 Brand  \
# 0  17/02/2022           5    Ice Cream           Dodla Dairy
# 1  01/12/2021           1         Milk                  Amul
# 2  28/02/2022           4       Yogurt           Dodla Dairy
# 3  09/06/2019           3       Cheese  Britannia Industries
# 4  14/12/2020           8   Buttermilk          Mother Dairy
#
#    Quantity (liters/kg)  Price per Unit  ...  Production Date  \
# 0                222.40           85.72  ...       27/12/2021
# ...

# %%
df['Total Land Area (acres)'].sort_values(ascending=False)
# Out:
# 2665    999.53
# 2985    999.39
# 1360    999.18
# 826     998.99
# 236     998.55
#          ...
# 3421     11.32
# 3434     10.91
# 324      10.32
# 4252     10.25
# 2619     10.17
# Name: Total Land Area (acres), Length: 4325, dtype: float64

# %%
df[df['Total Land Area (acres)']>=998.55].sort_values(by='Total Land Area (acres)',ascending=False)
# Out:
#         Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 2665  Chandigarh                   999.53              64    Medium
# 2985       Delhi                   999.39              83     Large
# 1360   Karnataka                   999.18              50     Large
# 826    Karnataka                   998.99              31    Medium
# 236   Tamil Nadu                   998.55             100    Medium
#
#             Date  Product ID Product Name         Brand  Quantity (liters/kg)  \
# 2665  25/08/2020           2       Butter          Amul                671.56
# 2985  10/08/2019           4       Yogurt          Amul                373.36
# 1360  14/02/2022           3       Cheese          Amul                801.44
# 826   04/07/2022           4       Yogurt  Mother Dairy                669.74
# 236   28/06/2019           7        Lassi           Raj                368.47
#
#       Price per Unit  ...  Production Date  Expiration Date  \
# ...

# %%
a=df['Total Land Area (acres)'].head(5)

# %%
x=sns.countplot(data=a,x=df['Location'])
for bars in x.containers:
    x.bar_label(bars)

plt.title('Most Land Provided',fontsize=20)
plt.show()

# %%
df.head()
# Out:
#         Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 0      Telangana                   310.84              96    Medium
# 1  Uttar Pradesh                    19.19              44     Large
# 2     Tamil Nadu                   581.69              24    Medium
# 3      Telangana                   908.00              89     Small
# 4    Maharashtra                   861.95              21    Medium
#
#          Date  Product ID Product Name                 Brand  \
# 0  17/02/2022           5    Ice Cream           Dodla Dairy
# 1  01/12/2021           1         Milk                  Amul
# 2  28/02/2022           4       Yogurt           Dodla Dairy
# 3  09/06/2019           3       Cheese  Britannia Industries
# 4  14/12/2020           8   Buttermilk          Mother Dairy
#
#    Quantity (liters/kg)  Price per Unit  ...  Production Date  \
# 0                222.40           85.72  ...       27/12/2021
# ...

# %%
explode=[0.2,0.0,0.0]
w=df['Farm Size'].value_counts()
labels=['Large','Medium','Small']
plt.pie(x=w,labels=labels,autopct='%1.2f%%',explode=explode,shadow=True)
plt.title('Farm Size Count')
plt.show()

# %%
df['Number of Cows'].value_counts().reset_index().head()
# Out:
#    index  Number of Cows
# 0     89              63
# 1     25              63
# 2     34              62
# 3     55              61
# 4     94              60

# %%
df['Product Name'].value_counts()
# Out:
# Curd          479
# Lassi         447
# Paneer        441
# Yogurt        437
# Buttermilk    435
# Butter        431
# Milk          429
# Ice Cream     423
# Ghee          402
# Cheese        401
# Name: Product Name, dtype: int64

# %%
df[(df['Product Name']=='Curd') & (df['Brand']=='Amul')]
# Out:
#         Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 17        Kerala                   412.69              88    Medium
# 39     Jharkhand                   373.77              79    Medium
# 82     Jharkhand                   175.31              69     Large
# 99       Gujarat                   305.81              66    Medium
# 140   Tamil Nadu                   976.02              95     Small
# ...          ...                      ...             ...       ...
# 3799   Rajasthan                    25.29              79     Small
# 4045  Chandigarh                   375.44              30     Large
# 4084     Gujarat                   184.38              12    Medium
# 4094   Karnataka                   195.39              92    Medium
# 4120       Bihar                   606.68              22    Medium
#
#             Date  Product ID Product Name Brand  Quantity (liters/kg)  \
# 17    24/06/2020           6         Curd  Amul                385.41
# ...

# %%
df['Brand'].value_counts()
# Out:
# Amul                    1053
# Mother Dairy            1010
# Raj                      685
# Sudha                    648
# Dodla Dairy              222
# Palle2patnam             211
# Dynamix Dairies          106
# Warana                   104
# Parag Milk Foods         102
# Passion Cheese            96
# Britannia Industries      88
# Name: Brand, dtype: int64

# %%
x=df['Product Name'].value_counts()
labels=['Curd','Lassi','Paneer','Yogurt','Buttermilk','Butter','Milk','Ice Cream','Ghee','Cheese']
plt.pie(x=x,labels=labels,autopct='%1.2f%%')
plt.show()

# %%
df['Approx. Total Revenue(INR)'].max()
# Out:
# 89108.9

# %%
df[df['Approx. Total Revenue(INR)']==89108.9]
# Out:
#          Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 3267  West Bengal                   774.49              42     Small
#
#             Date  Product ID Product Name Brand  Quantity (liters/kg)  \
# 3267  22/04/2022          10         Ghee   Raj                946.24
#
#       Price per Unit  ...  Production Date  Expiration Date  \
# 3267           95.16  ...       13/03/2022       07/08/2022
#
#      Quantity Sold (liters/kg) Price per Unit (sold)  \
# 3267                       901                  98.9
#
#      Approx. Total Revenue(INR)  Customer Location  Sales Channel  \
# 3267                    89108.9        West Bengal         Online
#
#       Quantity in Stock (liters/kg) Minimum Stock Threshold (liters/kg)  \
# 3267                             45                               28.53
#
#      Reorder Quantity (liters/kg)
# 3267                        41.19
#
# [1 rows x 23 columns]

# %%
matplotlib.rcParams['figure.figsize']=(7,5)
r=sns.countplot(x=df['Sales Channel'])
for bars in r.containers:
    r.bar_label(bars)

# %%
# ghee is the only product which has shelf life more than 100 days

df[df['Shelf Life (days)']>100]
# Out:
#             Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 16    Madhya Pradesh                   233.62              95     Large
# 33        Tamil Nadu                   589.36              97    Medium
# 36        Chandigarh                   750.03              81     Small
# 58             Delhi                   744.96              19    Medium
# 60         Rajasthan                   418.17              20     Large
# ...              ...                      ...             ...       ...
# 4251         Gujarat                   578.12              68     Small
# 4266          Kerala                   306.82              50    Medium
# 4277       Rajasthan                   381.39              96     Small
# 4283      Chandigarh                   576.52              53     Small
# 4292      Tamil Nadu                   208.38              86    Medium
#
#             Date  Product ID Product Name         Brand  Quantity (liters/kg)  \
# ...

# %%
m=df.groupby(df['Product Name'],as_index=False)['Quantity Sold (liters/kg)'].sum().sort_values(by='Quantity Sold (liters/kg)', ascending=False)

d=sns.barplot(x='Product Name', y='Quantity Sold (liters/kg)',data=m)
for bars in d.containers:
    d.bar_label(bars)

# %%
w=sns.barplot(x=df['Sales Channel'],y=df['Approx. Total Revenue(INR)'])
for bars in w.containers:
    w.bar_label(bars)

# %%
df.columns
# Out:
# Index(['Location', 'Total Land Area (acres)', 'Number of Cows', 'Farm Size',
#        'Date', 'Product ID', 'Product Name', 'Brand', 'Quantity (liters/kg)',
#        'Price per Unit', 'Total Value', 'Shelf Life (days)',
#        'Storage Condition', 'Production Date', 'Expiration Date',
#        'Quantity Sold (liters/kg)', 'Price per Unit (sold)',
#        'Approx. Total Revenue(INR)', 'Customer Location', 'Sales Channel',
#        'Quantity in Stock (liters/kg)', 'Minimum Stock Threshold (liters/kg)',
#        'Reorder Quantity (liters/kg)'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Total Land Area (acres)  Number of Cows   Product ID  \
# count              4325.000000     4325.000000  4325.000000
# mean                503.483073       54.963699     5.509595
# std                 285.935061       26.111487     2.842979
# min                  10.170000       10.000000     1.000000
# 25%                 252.950000       32.000000     3.000000
# 50%                 509.170000       55.000000     6.000000
# 75%                 751.250000       77.000000     8.000000
# max                 999.530000      100.000000    10.000000
#
#        Quantity (liters/kg)  Price per Unit   Total Value  Shelf Life (days)  \
# count           4325.000000     4325.000000   4325.000000        4325.000000
# mean             500.652657       54.785938  27357.845411          29.127630
# std              288.975915       26.002815  21621.051594          30.272114
# min                1.170000       10.030000     42.516500           1.000000
# ...

# %%
y=df.groupby(df['Sales Channel'],as_index=False)['Quantity Sold (liters/kg)'].sum().sort_values(by='Quantity Sold (liters/kg)',ascending=False)

sns.set(rc={'figure.figsize':(15,5)})
g=sns.barplot(x='Sales Channel',y='Quantity Sold (liters/kg)',data=y)

for bars in g.containers:
    g.bar_label(bars)

# %%
x=df.groupby(df['Storage Condition'],as_index=False)['Approx. Total Revenue(INR)'].sum().sort_values(by='Approx. Total Revenue(INR)',ascending=False)

h=sns.barplot(x='Storage Condition',y='Approx. Total Revenue(INR)',data=x)

for bars in h.containers:
    h.bar_label(bars)

# %%
matplotlib.rcParams['figure.figsize']=(20,5)
x=df.groupby(df['Location'],as_index=False)['Total Land Area (acres)'].sum().sort_values(by='Total Land Area (acres)',ascending=False)

h=sns.barplot(x='Location',y='Total Land Area (acres)',data=x)

for bars in h.containers:
    h.bar_label(bars)

# %%
matplotlib.rcParams['figure.figsize']=(20,5)
x=df.groupby(df['Product Name'],as_index=False)['Quantity Sold (liters/kg)'].sum().sort_values(by='Quantity Sold (liters/kg)',ascending=False)

h=sns.barplot(x='Product Name',y='Quantity Sold (liters/kg)',data=x)

for bars in h.containers:
    h.bar_label(bars)

# %%
df.head(1)
# Out:
#     Location  Total Land Area (acres)  Number of Cows Farm Size        Date  \
# 0  Telangana                   310.84              96    Medium  17/02/2022
#
#    Product ID Product Name        Brand  Quantity (liters/kg)  Price per Unit  \
# 0           5    Ice Cream  Dodla Dairy                 222.4           85.72
#
#    ...  Production Date  Expiration Date Quantity Sold (liters/kg)  \
# 0  ...       27/12/2021       21/01/2022                         7
#
#   Price per Unit (sold) Approx. Total Revenue(INR)  Customer Location  \
# 0                 82.24                     575.68     Madhya Pradesh
#
#    Sales Channel  Quantity in Stock (liters/kg)  \
# 0      Wholesale                            215
#
#   Minimum Stock Threshold (liters/kg) Reorder Quantity (liters/kg)
# 0                               19.55                        64.03
#
# [1 rows x 23 columns]

# %%
g=df.groupby(df['Brand'],as_index=False)['Quantity Sold (liters/kg)'].sum().sort_values(by='Quantity Sold (liters/kg)',ascending=True)

p=sns.barplot(x='Brand',y='Quantity Sold (liters/kg)',data=g)
for bars in p.containers:
    p.bar_label(bars)
